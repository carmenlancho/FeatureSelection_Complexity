# %% [markdown]
# # Comparación datos reales

# %% [markdown]
# Hemos ejecutado los resultados con algunos datos reales (no muy muy grandes) para analizar el comportamiento de nuestro método. Sobre todo por si estamos generando los datasets artificiales de forma errónea.

# %%
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
from IPython.display import display

# from Comparison_RealDatasets import *

# %%
import os
os.chdir("..")
root_path = os.getcwd()
from Comparison_RealDatasets import *

# %%
root_path
# Out:
# '/home/carmen/PycharmProjects/FeatureSelection_Complexity'

# %% [markdown]
# ## Comparación valores performances con número de variables (k) fijo

# %%
df_compl = pd.read_csv("Results_FS_Distributed_CV/spambase_DistributedCVRandom_OutHigh_SummaryResults.csv")
df_sota = pd.read_csv("Results_FS_SOTA_CV/spambase_SOTA_CV_SummaryResults.csv")

df_comparison = build_comparison_table(df_compl, df_sota)
display(df_comparison)
# Out:
#       model                method  acc_test_mean  acc_test_std  gps_test_mean  \
# 0       KNN  kDN_importances_norm       0.900154      0.005782       0.893778
# 1   SVM-rbf  kDN_importances_norm       0.904068      0.006983       0.897583
# 2       KNN             f_classif       0.899282      0.008893       0.892019
# 3       KNN           mutual_info       0.900809      0.014833       0.894253
# 4       KNN                relief       0.903201      0.010486       0.896968
# 5       KNN                    rf       0.914072      0.010954       0.909155
# 6       KNN                   xgb       0.902759      0.010118       0.898156
# 7   SVM-rbf             f_classif       0.915162      0.007217       0.909819
# 8   SVM-rbf           mutual_info       0.917555      0.003652       0.912510
# 9   SVM-rbf                relief       0.918424      0.003395       0.913157
# 10  SVM-rbf                    rf       0.925167      0.009728       0.920595
# 11  SVM-rbf                   xgb       0.926254      0.007993       0.922072
#
#     gps_test_std
# 0       0.006771
# 1       0.007841
# 2       0.010414
# 3       0.016133
# 4       0.011947
# 5       0.011651
# 6       0.010361
# 7       0.008054
# 8       0.004091
# 9       0.003294
# 10      0.010460
# 11      0.008532

# %% [markdown]
# RF y XGB son los mejores. Nosotros reguleras.

# %%
df_compl = pd.read_csv("Results_FS_Distributed_CV/sonar_DistributedCVRandom_OutHigh_SummaryResults.csv")
df_sota = pd.read_csv("Results_FS_SOTA_CV/sonar_SOTA_CV_SummaryResults.csv")

df_comparison = build_comparison_table(df_compl, df_sota)
display(df_comparison)
# Out:
#       model                method  acc_test_mean  acc_test_std  gps_test_mean  \
# 0       KNN  kDN_importances_norm       0.827178      0.079166       0.820145
# 1   SVM-rbf  kDN_importances_norm       0.817654      0.063429       0.810984
# 2       KNN             f_classif       0.798026      0.059950       0.789738
# 3       KNN           mutual_info       0.812544      0.074006       0.805413
# 4       KNN                relief       0.826829      0.066584       0.821932
# 5       KNN                    rf       0.798374      0.082802       0.789601
# 6       KNN                   xgb       0.802787      0.062002       0.796183
# 7   SVM-rbf             f_classif       0.769686      0.085622       0.757546
# 8   SVM-rbf           mutual_info       0.817654      0.056328       0.808479
# 9   SVM-rbf                relief       0.827062      0.045193       0.822214
# 10  SVM-rbf                    rf       0.803484      0.102402       0.797485
# 11  SVM-rbf                   xgb       0.803368      0.082081       0.796724
#
#     gps_test_std
# 0       0.088078
# 1       0.072611
# 2       0.067128
# 3       0.078354
# 4       0.068725
# 5       0.094893
# 6       0.066392
# 7       0.100090
# 8       0.070131
# 9       0.047010
# 10      0.112814
# 11      0.089517

# %% [markdown]
# Nosotros bastante bien, muy en el top

# %%
df_compl = pd.read_csv("Results_FS_Distributed_CV/ionosphere_DistributedCVRandom_OutHigh_SummaryResults.csv")
df_sota = pd.read_csv("Results_FS_SOTA_CV/ionosphere_SOTA_CV_SummaryResults.csv")

df_comparison = build_comparison_table(df_compl, df_sota)
display(df_comparison)
# Out:
#       model                method  acc_test_mean  acc_test_std  gps_test_mean  \
# 0       KNN  kDN_importances_norm       0.866157      0.029210       0.836344
# 1   SVM-rbf  kDN_importances_norm       0.934648      0.036490       0.926058
# 2       KNN             f_classif       0.863501      0.066377       0.836312
# 3       KNN           mutual_info       0.863340      0.040665       0.829106
# 4       KNN                relief       0.871871      0.026147       0.844451
# 5       KNN                    rf       0.871831      0.031731       0.843532
# 6       KNN                   xgb       0.886237      0.041769       0.861977
# 7   SVM-rbf             f_classif       0.917465      0.030568       0.906429
# 8   SVM-rbf           mutual_info       0.948813      0.029277       0.943011
# 9   SVM-rbf                relief       0.931751      0.032015       0.923689
# 10  SVM-rbf                    rf       0.948853      0.027234       0.942650
# 11  SVM-rbf                   xgb       0.928893      0.026083       0.920879
#
#     gps_test_std
# 0       0.041987
# 1       0.042687
# 2       0.080524
# 3       0.055747
# 4       0.035409
# 5       0.040880
# 6       0.057474
# 7       0.035506
# 8       0.033030
# 9       0.036258
# 10      0.031783
# 11      0.030071

# %% [markdown]
# Nos supera RF y mutual-info en svm, con knn estamos los cuartos

# %%
df_compl = pd.read_csv("Results_FS_Distributed_CV/wdbc_DistributedCVRandom_OutHigh_SummaryResults.csv")
df_sota = pd.read_csv("Results_FS_SOTA_CV/wdbc_SOTA_CV_SummaryResults.csv")

df_comparison = build_comparison_table(df_compl, df_sota)
display(df_comparison)
# Out:
#       model                method  acc_test_mean  acc_test_std  gps_test_mean  \
# 0       KNN  kDN_importances_norm       0.964850      0.013870       0.961897
# 1   SVM-rbf  kDN_importances_norm       0.968390      0.014641       0.965703
# 2       KNN             f_classif       0.947275      0.016412       0.943069
# 3       KNN           mutual_info       0.952569      0.007725       0.948220
# 4       KNN                relief       0.949030      0.020953       0.944867
# 5       KNN                    rf       0.945474      0.024519       0.941292
# 6       KNN                   xgb       0.957848      0.014350       0.954111
# 7   SVM-rbf             f_classif       0.968359      0.007882       0.965893
# 8   SVM-rbf           mutual_info       0.963111      0.011384       0.960197
# 9   SVM-rbf                relief       0.966605      0.009624       0.963920
# 10  SVM-rbf                    rf       0.970129      0.004763       0.967827
# 11  SVM-rbf                   xgb       0.966620      0.007284       0.963865
#
#     gps_test_std
# 0       0.015039
# 1       0.016148
# 2       0.017447
# 3       0.009193
# 4       0.022844
# 5       0.026268
# 6       0.016085
# 7       0.008621
# 8       0.012434
# 9       0.010678
# 10      0.005511
# 11      0.008284

# %% [markdown]
# Solo nos supera RF en SVM

# %%
df_compl = pd.read_csv("Results_FS_Distributed_CV/parkinsons_DistributedCVRandom_OutHigh_SummaryResults.csv")
df_sota = pd.read_csv("Results_FS_SOTA_CV/parkinsons_SOTA_CV_SummaryResults.csv")

df_comparison = build_comparison_table(df_compl, df_sota)
display(df_comparison)
# Out:
#       model                method  acc_test_mean  acc_test_std  gps_test_mean  \
# 0       KNN  kDN_importances_norm       0.897436      0.018131       0.852499
# 1   SVM-rbf  kDN_importances_norm       0.887179      0.034401       0.799949
# 2       KNN             f_classif       0.917949      0.021453       0.886968
# 3       KNN           mutual_info       0.907692      0.022934       0.866739
# 4       KNN                relief       0.923077      0.025641       0.889881
# 5       KNN                    rf       0.912821      0.046579       0.872358
# 6       KNN                   xgb       0.902564      0.028088       0.861110
# 7   SVM-rbf             f_classif       0.861538      0.046579       0.734724
# 8   SVM-rbf           mutual_info       0.871795      0.025641       0.778809
# 9   SVM-rbf                relief       0.887179      0.034401       0.807525
# 10  SVM-rbf                    rf       0.876923      0.042133       0.778555
# 11  SVM-rbf                   xgb       0.871795      0.036262       0.771149
#
#     gps_test_std
# 0       0.029262
# 1       0.075672
# 2       0.030924
# 3       0.041133
# 4       0.037692
# 5       0.073683
# 6       0.042681
# 7       0.125559
# 8       0.062133
# 9       0.064323
# 10      0.090485
# 11      0.082321

# %% [markdown]
# En knn no vamos bien, en svm competimos solo con relief

# %% [markdown]
# ## Comparación de rankings

# %% [markdown]
# Está ordenado por nuestro método.
#
# Las que se eliminan en el primer filtro de correlación >=0.9 no se muestran aquí.

# %%
df_compl_fi = pd.read_csv("Results_FS_Distributed_CV/wdbc_DistributedCVRandom_OutHigh_FeatureImportance_Folds.csv")
df_sota_fi = pd.read_csv("Results_FS_SOTA_CV/wdbc_SOTA_CV_FeatureImportance_Folds.csv")
df_rank, df_all = ranks_comparison(df_sota_fi,df_compl_fi)
ranking_table = build_ranking_table(df_all,model="SVM-rbf")
display(ranking_table)
# Out:
#                    mean_rank                                                 \
# method             f_classif kDN_importances mutual_info relief    rf   xgb
# feature
# Radius1                  1.0             1.2         1.4    1.0   1.4   2.0
# Concavity3               3.0             2.2         3.0    3.0   3.0   3.0
# Concavity1               2.0             3.0         1.6    2.0   1.6   1.6
# Radius2                  5.6             3.6         4.0    6.2   4.0   9.2
# Texture1                 8.2             5.6        10.2    7.2   7.0   6.8
# Concavity2              15.0             8.6         7.2   15.6   8.4   7.0
# Fractal_dimension1      18.8             9.4        17.8   12.2  12.2  12.4
# Symmetry3                8.8             9.6        10.6   11.0  10.0  13.0
# Compactness1             4.4             9.8         5.6    4.0   6.0  12.8
# Compactness3             5.0            10.2         5.4    5.0   5.0  10.8
# Smoothness3              8.0            10.2        12.0    7.6   9.4   4.4
# Smoothness1             11.0            11.6        10.6   11.0  13.4  10.0
# Fractal_dimension2      16.4            13.6        16.2   19.0  17.0  17.4
# Concave_points2          9.0            14.0         8.4    9.0  10.4  19.4
# Symmetry1               12.2            14.4        13.2   15.4  18.6  13.2
# Symmetry2               18.8            15.4        16.6   18.0  17.6  14.4
# Smoothness2             16.6            16.2        18.4   17.4  19.2  10.8
# Fractal_dimension3      12.8            16.4        16.0   13.2  15.4  14.0
# Compactness2            14.0            17.4        12.6   12.6  13.2  11.4
# Texture2                19.4            17.6        19.2   19.6  17.2  16.4
#
#                     std_rank                                                  \
# method             f_classif kDN_importances mutual_info    relief        rf
# feature
# Radius1             0.000000        0.447214    0.547723  0.000000  0.547723
# Concavity3          0.000000        0.836660    0.000000  0.000000  0.000000
# Concavity1          0.000000        1.000000    0.547723  0.000000  0.547723
# Radius2             0.894427        0.547723    0.000000  0.447214  0.000000
# Texture1            1.303840        0.894427    2.280351  0.447214  0.000000
# Concavity2          0.000000        4.827007    0.447214  0.547723  0.547723
# Fractal_dimension1  0.836660        1.816590    0.836660  1.303840  1.095445
# Symmetry3           0.836660        3.049590    0.894427  1.414214  1.414214
# Compactness1        0.547723        3.898718    0.547723  0.000000  0.000000
# Compactness3        0.707107        5.167204    0.547723  0.000000  0.000000
# Smoothness3         1.000000        4.324350    1.414214  0.894427  1.140175
# Smoothness1         0.000000        2.607681    2.073644  0.707107  0.547723
# Fractal_dimension2  0.547723        1.816590    0.836660  0.707107  1.870829
# Concave_points2     1.414214        5.656854    0.894427  0.000000  0.894427
# Symmetry1           0.447214        1.673320    1.303840  0.547723  0.894427
# Symmetry2           0.836660        2.701851    2.302173  1.224745  1.673320
# Smoothness2         0.547723        2.387467    2.073644  0.547723  1.303840
# Fractal_dimension3  0.447214        2.302173    2.345208  0.836660  0.547723
# Compactness2        0.000000        4.159327    2.966479  1.673320  0.836660
# Texture2            0.894427        2.190890    0.447214  0.547723  1.303840
#
#
# method                   xgb
# feature
# Radius1             0.707107
# Concavity3          0.707107
# Concavity1          1.341641
# Radius2             1.643168
# Texture1            1.303840
# Concavity2          2.549510
# Fractal_dimension1  3.435113
# Symmetry3           2.828427
# Compactness1        2.774887
# Compactness3        5.540758
# Smoothness3         0.894427
# Smoothness1         4.415880
# Fractal_dimension2  2.607681
# Concave_points2     1.341641
# Symmetry1           6.610598
# Symmetry2           2.509980
# Smoothness2         6.379655
# Fractal_dimension3  4.301163
# Compactness2        3.507136
# Texture2            1.516575

# %%
model_name = "SVM-rbf"
corr_mean = spearman_per_fold(df_rank, model_name)

plot_corrplot(corr_mean,title=f"Mean Spearman correlation across folds ({model_name})")

# %%
model_name = "KNN"
corr_mean = spearman_per_fold(df_rank, model_name)

plot_corrplot(corr_mean,title=f"Mean Spearman correlation across folds ({model_name})")

# %%
df_compl_fi = pd.read_csv("Results_FS_Distributed_CV/spambase_DistributedCVRandom_OutHigh_FeatureImportance_Folds.csv")
df_sota_fi = pd.read_csv("Results_FS_SOTA_CV/spambase_SOTA_CV_FeatureImportance_Folds.csv")
df_rank, df_all = ranks_comparison(df_sota_fi,df_compl_fi)
ranking_table = build_ranking_table(df_all,model="SVM-rbf")
display(ranking_table)
# Out:
#                            mean_rank                                           \
# method                     f_classif kDN_importances mutual_info relief    rf
# feature
# Word_freq_remove                 3.0             2.6         6.0   10.8   3.0
# Char_freq4                      11.8             4.8         1.0    7.0   1.0
# Char_freq5                       3.4             9.8         2.6    7.6   2.0
# Word_freq_free                   8.0            10.0         7.6    6.4   4.6
# Capital_run_length_average      40.2            10.8         4.0   44.8   4.4
# Word_freq_order                 13.4            16.8        26.4   24.8  35.0
# Word_freq_000                    2.6            17.6        13.0   13.6  13.2
# Word_freq_business               6.8            18.4        18.6   23.0  21.2
# Word_freq_money                 16.2            18.4         9.8   31.8  10.4
# Word_freq_hp                     8.0            18.6        11.0    4.4   8.2
# Word_freq_over                  13.4            19.2        22.4   28.8  26.0
# Word_freq_credit                22.0            22.8        27.2   44.6  33.0
# Capital_run_length_longest      15.2            23.0         2.4   35.8   6.2
# Word_freq_you                    6.0            23.0         9.8    2.4  11.2
# Word_freq_font                  44.0            23.4        42.2   37.2  42.4
# Word_freq_our                   10.4            24.0        12.8    8.8  11.4
# Capital_run_length_total        10.0            25.0         7.6   12.8   8.4
# Word_freq_hpl                   12.8            25.0        15.8   16.4  15.8
# Word_freq_lab                   33.0            25.0        28.2   38.6  45.2
# Word_freq_internet              18.4            25.6        18.8   35.0  18.2
# Word_freq_re                    30.4            26.0        26.0   24.0  22.8
# Word_freq_857                   40.0            26.8        44.6   20.6  52.8
# Word_freq_mail                  31.6            27.4        20.0   29.4  25.4
# Word_freq_your                   1.0            28.0         5.0    2.4   7.2
# Word_freq_george                23.0            28.2        12.4    1.2  13.8
# Word_freq_conference            45.4            28.4        50.4   56.0  49.6
# Word_freq_receive               12.8            28.4        16.4   20.2  23.2
# Word_freq_addresses             20.2            30.0        37.0   30.2  49.0
# Word_freq_1999                  23.8            30.2        30.2   21.6  18.8
# Word_freq_pm                    37.8            30.2        48.4   45.2  38.8
# Word_freq_edu                   28.0            30.4        34.6   27.0  15.2
# Word_freq_technology            32.6            30.6        48.4   16.6  39.0
# Word_freq_project               43.4            31.4        45.2   52.4  45.8
# Word_freq_email                 18.0            32.0        23.2   36.4  26.2
# Char_freq6                      48.0            32.2        31.6   54.4  35.2
# Word_freq_original              32.2            33.4        42.0   32.8  48.0
# Char_freq1                      50.2            33.6        38.4   35.2  30.2
# Word_freq_labs                  25.0            33.6        35.0   13.6  36.8
# Word_freq_telnet                35.8            33.8        37.8   32.2  47.6
# Word_freq_cs                    42.8            34.0        49.2   48.6  51.8
# Word_freq_meeting               31.4            34.4        38.0   45.0  29.8
# Char_freq2                      44.4            34.6        27.6   24.4  18.0
# Word_freq_direct                48.8            35.0        54.9   22.8  50.2
# Word_freq_make                  36.4            35.2        36.0   37.8  36.0
# Word_freq_data                  38.8            36.0        48.0   45.8  41.2
# Word_freq_table                 53.0            36.0        54.2   51.0  56.0
# Word_freq_people                33.6            38.0        30.6   42.8  36.4
# Word_freq_parts                 54.6            38.8        48.2   53.8  55.0
# Word_freq_report                50.6            39.0        52.6   40.0  44.8
# Char_freq3                      48.6            39.2        48.8   50.2  40.8
# Word_freq_85                    27.8            39.2        34.2   36.2  35.4
# Word_freq_3d                    50.8            40.0        55.5   52.0  53.4
# Word_freq_all                   20.0            40.2        16.2   15.6  21.6
# Word_freq_address               54.4            42.6        22.0   22.0  29.0
# Word_freq_650                   26.2            47.6        40.6   16.8  29.8
# Word_freq_will                  56.0            47.8        25.6    5.2  20.6
#
#                                   std_rank                              \
# method                       xgb f_classif kDN_importances mutual_info
# feature
# Word_freq_remove             1.8  0.707107        1.341641    0.000000
# Char_freq4                   3.0  3.834058        2.683282    0.000000
# Char_freq5                   1.2  0.894427       11.031772    0.547723
# Word_freq_free              10.0  1.870829       13.057565    0.547723
# Capital_run_length_average  15.2  1.095445        5.449771    0.000000
# Word_freq_order             46.2  2.509980        7.918333    2.073644
# Word_freq_000               11.8  0.894427       19.204166    1.414214
# Word_freq_business          12.6  1.923538       13.867228    1.816590
# Word_freq_money              6.4  2.167948       18.981570    1.483240
# Word_freq_hp                 4.0  1.224745       16.935171    1.224745
# Word_freq_over              33.2  2.880972        9.884331    2.073644
# Word_freq_credit            31.0  1.224745       16.634302    3.563706
# Capital_run_length_longest  18.0  5.718391       17.204651    0.547723
# Word_freq_you               39.8  1.000000       13.133926    0.836660
# Word_freq_font              18.2  1.581139       10.430724    1.643168
# Word_freq_our               13.2  3.209361       15.116216    1.643168
# Capital_run_length_total    28.8  2.236068       14.628739    0.894427
# Word_freq_hpl               19.0  1.643168       17.832555    1.303840
# Word_freq_lab               28.8  2.738613        9.137833    2.774887
# Word_freq_internet          17.4  2.073644       19.831793    0.447214
# Word_freq_re                19.8  1.516575       15.247951    2.549510
# Word_freq_857               53.8  0.707107        6.300794    1.516575
# Word_freq_mail              36.4  3.781534       13.974978    1.870829
# Word_freq_your              20.8  0.000000       17.248188    0.000000
# Word_freq_george             5.4  0.707107       15.188812    0.894427
# Word_freq_conference        29.4  0.894427       18.256506    0.894427
# Word_freq_receive           27.6  1.643168       14.099645    0.894427
# Word_freq_addresses         40.3  1.303840       17.146428    2.236068
# Word_freq_1999              14.2  1.095445       15.385058    2.387467
# Word_freq_pm                26.8  1.483240       12.397580    2.302173
# Word_freq_edu                8.0  1.000000       15.598077    5.594640
# Word_freq_technology        24.8  1.516575       17.896927    4.335897
# Word_freq_project           31.0  1.140175       16.164777    2.683282
# Word_freq_email             28.0  2.738613       15.247951    2.949576
# Char_freq6                  45.2  1.224745        8.348653    3.911521
# Word_freq_original          35.8  2.280351       10.526158    1.000000
# Char_freq1                  31.0  1.303840       10.549882    4.615192
# Word_freq_labs              49.5  0.707107        6.228965    1.581139
# Word_freq_telnet            53.8  1.923538       29.499153    1.303840
# Word_freq_cs                27.6  0.836660        9.899495    1.923538
# Word_freq_meeting           10.0  1.516575       21.054691    2.449490
# Char_freq2                  40.4  1.516575       18.501351    3.209361
# Word_freq_direct            50.0  1.303840       13.982131    1.083974
# Word_freq_make              37.4  3.781534        7.190271    3.162278
# Word_freq_data              42.6  1.483240       14.560220    2.549510
# Word_freq_table             53.8  0.000000        6.964194    0.836660
# Word_freq_people            36.8  3.361547       16.777962    4.277850
# Word_freq_parts             53.8  0.547723       16.828547    3.114482
# Word_freq_report            37.0  2.073644       13.322913    1.516575
# Char_freq3                  47.0  1.140175       12.437845    3.420526
# Word_freq_85                45.4  1.923538       14.042792    3.898718
# Word_freq_3d                48.8  1.643168        9.513149    0.353553
# Word_freq_all               42.2  1.000000       10.802777    1.095445
# Word_freq_address           35.0  0.547723       20.218803    1.870829
# Word_freq_650               10.8  0.447214       17.155174    3.911521
# Word_freq_will              36.2  0.000000        6.140033    3.286335
#
#
# method                         relief        rf        xgb
# feature
# Word_freq_remove             0.836660  0.000000   0.447214
# Char_freq4                   1.224745  0.000000   0.000000
# Char_freq5                   1.516575  0.000000   0.447214
# Word_freq_free               1.140175  0.547723   2.121320
# Capital_run_length_average   1.643168  0.547723   4.086563
# Word_freq_order              7.758866  3.391165   1.483240
# Word_freq_000                2.073644  0.447214   3.563706
# Word_freq_business           6.041523  1.303840   3.435113
# Word_freq_money              1.483240  0.894427   1.673320
# Word_freq_hp                 0.547723  0.447214   0.000000
# Word_freq_over               1.923538  1.000000   9.679876
# Word_freq_credit             8.473488  3.535534   4.242641
# Capital_run_length_longest  13.405223  0.447214   3.674235
# Word_freq_you                0.547723  0.447214   3.768289
# Word_freq_font               2.489980  3.781534   8.258329
# Word_freq_our                1.095445  0.894427   3.962323
# Capital_run_length_total     3.834058  0.894427   1.923538
# Word_freq_hpl                3.049590  0.447214   3.535534
# Word_freq_lab                5.029911  2.280351   6.723095
# Word_freq_internet           3.535534  1.095445   7.368853
# Word_freq_re                 1.224745  0.836660   1.923538
# Word_freq_857                1.516575  0.836660   0.447214
# Word_freq_mail               3.847077  1.516575   4.335897
# Word_freq_your               0.894427  1.095445   2.280351
# Word_freq_george             0.447214  0.447214   0.547723
# Word_freq_conference         0.000000  0.894427   8.324662
# Word_freq_receive            4.438468  1.923538   5.549775
# Word_freq_addresses          5.263079  2.449490  14.069470
# Word_freq_1999               3.507136  2.949576   3.346640
# Word_freq_pm                 2.774887  2.280351   7.014271
# Word_freq_edu                4.527693  0.447214   2.345208
# Word_freq_technology         3.781534  2.236068  11.670476
# Word_freq_project            1.341641  1.483240   8.514693
# Word_freq_email              4.722288  0.836660   7.106335
# Char_freq6                   1.341641  1.303840   3.563706
# Word_freq_original           2.167948  1.732051   6.906519
# Char_freq1                   2.588436  1.095445   3.162278
# Word_freq_labs               2.190890  3.834058   3.041381
# Word_freq_telnet            10.232302  3.209361   0.447214
# Word_freq_cs                 1.140175  2.049390   7.266361
# Word_freq_meeting            1.224745  1.303840   1.000000
# Char_freq2                   6.655825  0.707107   4.098780
# Word_freq_direct             1.643168  1.643168   6.354133
# Word_freq_make               2.280351  1.224745   4.929503
# Word_freq_data               6.140033  1.788854   5.128353
# Word_freq_table              1.224745  0.000000   0.447214
# Word_freq_people             2.588436  2.302173  12.597619
# Word_freq_parts              0.447214  0.000000   0.447214
# Word_freq_report             4.000000  0.836660  10.885771
# Char_freq3                   2.774887  1.788854   3.535534
# Word_freq_85                14.113823  3.209361   5.639149
# Word_freq_3d                 0.707107  0.547723   4.957318
# Word_freq_all                1.516575  1.516575   5.019960
# Word_freq_address            2.236068  1.224745   3.535534
# Word_freq_650                1.923538  2.167948   5.761944
# Word_freq_will               1.303840  1.140175   2.949576

# %%
model_name = "SVM-rbf"
corr_mean = spearman_per_fold(df_rank, model_name)

plot_corrplot(corr_mean,title=f"Mean Spearman correlation across folds ({model_name})")

# %%
model_name = "KNN"
corr_mean = spearman_per_fold(df_rank, model_name)

plot_corrplot(corr_mean,title=f"Mean Spearman correlation across folds ({model_name})")

# %%
df_compl_fi = pd.read_csv("Results_FS_Distributed_CV/parkinsons_DistributedCVRandom_OutHigh_FeatureImportance_Folds.csv")
df_sota_fi = pd.read_csv("Results_FS_SOTA_CV/parkinsons_SOTA_CV_FeatureImportance_Folds.csv")
df_rank, df_all = ranks_comparison(df_sota_fi,df_compl_fi)
ranking_table = build_ranking_table(df_all,model="SVM-rbf")
display(ranking_table)
# Out:
#         mean_rank                                                 std_rank  \
# method  f_classif kDN_importances mutual_info relief    rf   xgb f_classif
# feature
# V1            4.4             1.2         2.0    1.8   2.2   3.2  0.894427
# V19           1.0             2.6         1.4    2.2   1.2   1.0  0.000000
# V2           10.8             4.2         4.4    7.0   4.6   5.0  0.447214
# V20           2.0             4.8         4.0    4.0   2.8   7.2  0.000000
# V18          10.2             5.8         8.0    9.2  10.4   8.4  0.447214
# V3            4.2             6.0         3.6    2.0   4.6  11.0  1.643168
# V4            8.8             6.8         7.2   11.0   8.2   6.4  0.447214
# V9            4.8             7.0         8.0    9.4   6.6   3.2  1.643168
# V21           6.6             8.6        11.0    8.0   7.0   6.6  1.140175
# V16           5.8             8.8         7.0    6.2   8.8   7.4  1.303840
# V17           7.4            10.2         9.4    5.2   9.6   6.6  1.949359
#
#
# method  kDN_importances mutual_info    relief        rf       xgb
# feature
# V1             0.447214    0.707107  0.836660  0.836660  0.447214
# V19            1.949359    0.894427  1.095445  0.447214  0.000000
# V2             0.836660    0.547723  1.224745  0.547723  1.224745
# V20            2.280351    2.000000  0.000000  0.836660  1.923538
# V18            3.114482    1.000000  0.836660  0.894427  0.894427
# V3             3.741657    1.140175  0.707107  1.516575  0.000000
# V4             1.303840    1.303840  0.000000  1.788854  2.701851
# V9             2.000000    1.870829  0.547723  0.894427  2.683282
# V21            1.949359    0.000000  1.224745  1.870829  2.792848
# V16            1.095445    1.414214  0.447214  1.303840  2.509980
# V17            1.303840    1.341641  0.447214  0.894427  2.607681

# %%
model_name = "SVM-rbf"
corr_mean = spearman_per_fold(df_rank, model_name)

plot_corrplot(corr_mean,title=f"Mean Spearman correlation across folds ({model_name})")

# %%
model_name = "KNN"
corr_mean = spearman_per_fold(df_rank, model_name)

plot_corrplot(corr_mean,title=f"Mean Spearman correlation across folds ({model_name})")

# %%
df_compl_fi = pd.read_csv("Results_FS_Distributed_CV/sonar_DistributedCVRandom_OutHigh_FeatureImportance_Folds.csv")
df_sota_fi = pd.read_csv("Results_FS_SOTA_CV/sonar_SOTA_CV_FeatureImportance_Folds.csv")
df_rank, df_all = ranks_comparison(df_sota_fi,df_compl_fi)
ranking_table = build_ranking_table(df_all,model="SVM-rbf")
display(ranking_table)
# Out:
#         mean_rank                                                    \
# method  f_classif kDN_importances mutual_info     relief         rf
# feature
# V12           2.0             2.6    1.400000   1.600000   2.200000
# V9            7.4             4.2    8.200000   8.000000   4.200000
# V10           5.2             8.0   10.400000   4.400000   5.000000
# V48           5.8            10.4    7.200000   9.000000   7.600000
# V11           1.0            10.8    2.000000   1.400000   1.200000
# V45           4.4            12.6   24.400000   8.800000  12.000000
# V27          47.2            14.2   49.500000  33.200000  18.800000
# V22          24.0            14.4   25.200000  15.800000  29.400000
# V21          22.0            14.5   14.500000   8.000000  24.500000
# V15          47.0            14.6   33.800000  37.000000  21.200000
# V36          13.8            15.2   26.900000   5.400000  12.000000
# V46           9.8            16.0   13.200000  14.200000  19.400000
# V43          19.4            16.4   21.000000  19.200000  27.400000
# V49           4.0            18.0    3.666667   6.333333  10.333333
# V47          10.4            18.2   24.800000  15.400000   8.400000
# V37          23.0            18.8   17.200000  11.800000  16.200000
# V13           7.8            19.8   23.600000   5.600000  11.600000
# V28          41.8            19.8   34.700000  31.000000  18.400000
# V20          20.2            20.2   24.300000   8.800000  16.800000
# V23          34.2            20.2   24.400000  24.400000  26.800000
# V31          39.0            20.6   41.900000  30.000000  24.000000
# V17          52.0            21.0   13.333333  35.666667  14.333333
# V44          13.2            22.4   35.500000  16.000000  19.400000
# V26          51.8            22.8   44.500000  51.600000  37.200000
# V4           16.4            27.2   40.600000  29.600000  17.800000
# V32          47.2            28.6   40.600000  37.600000  38.000000
# V39          47.6            28.8   30.000000  39.200000  25.400000
# V2           19.2            29.2   29.700000  33.400000  41.000000
# V8           26.0            29.6   14.400000  23.400000  35.200000
# V35          19.8            30.0   44.800000  13.800000  27.000000
# V51          10.2            30.2   36.200000  17.600000   7.000000
# V52          11.6            32.4   27.800000  20.200000  12.600000
# V40          46.2            32.8   26.100000  45.000000  41.400000
# V41          50.2            34.0   45.000000  48.200000  46.800000
# V30          51.6            34.4   29.500000  43.600000  43.600000
# V55          41.8            35.0   27.600000  51.000000  43.200000
# V29          49.4            36.0   30.700000  44.000000  42.600000
# V58          26.4            36.0   10.400000  41.400000  42.600000
# V24          43.6            36.2   31.800000  43.000000  41.200000
# V6           35.2            36.4   41.400000  23.200000  25.600000
# V34          28.6            36.6   45.700000  20.200000  44.400000
# V25          50.8            37.6   21.300000  48.800000  48.600000
# V38          49.0            38.6   32.900000  48.600000  40.400000
# V59          34.4            38.7   19.200000  46.600000  37.800000
# V1           14.2            39.9   32.000000  23.600000  30.000000
# V14          30.6            40.4   24.600000  26.600000  30.800000
# V3           25.2            40.6   34.100000  42.400000  41.600000
# V5           21.6            40.8   19.800000  26.800000  16.200000
# V60          42.2            41.0   39.200000  56.000000  47.800000
# V19          33.8            41.2   36.100000  31.600000  38.400000
# V53          34.0            42.8   43.500000  45.000000  49.400000
# V50          27.0            43.0   47.400000  33.200000  42.800000
# V54          26.4            43.4   36.800000  35.200000  35.400000
# V7           38.0            45.4   20.000000  37.000000  45.000000
# V42          32.8            46.4   40.900000  31.600000  40.200000
# V56          35.2            46.7   45.400000  51.400000  51.800000
# V33          39.6            47.2   31.900000  34.800000  46.000000
# V57          53.6            51.7   42.700000  55.600000  48.800000
#
#                      std_rank                                         \
# method         xgb  f_classif kDN_importances mutual_info     relief
# feature
# V12      20.800000   0.000000        2.607681    0.547723   0.547723
# V9       18.000000   1.140175        3.114482    4.324350   0.707107
# V10      27.400000   2.280351        6.164414    4.929503   1.140175
# V48      27.600000   2.774887        4.878524    3.701351   1.414214
# V11       1.000000   0.000000        9.093954    1.224745   0.547723
# V45       9.400000   1.140175        5.412947   14.791890   3.271085
# V27       8.200000   7.596052       11.256109    1.903943   8.467585
# V22      17.200000   7.106335        3.049590    6.685806   3.962323
# V21      32.000000   7.071068       17.677670    9.192388   2.828427
# V15       8.200000   7.648529       13.758634   19.616957   6.164414
# V36      26.000000   6.572671       13.330416   17.408331   4.335897
# V46      30.800000   2.863564        7.648529    8.136338   3.033150
# V43      37.800000   5.079370        3.911521   11.291590   5.310367
# V49      18.333333   1.000000       10.440307    0.577350   2.081666
# V47      12.600000   2.302173       17.020576   10.232302   2.190890
# V37      25.200000   6.000000       21.004761   12.132601   3.701351
# V13      50.600000   3.271085       14.463748   11.304866   2.701851
# V28      20.200000   9.093954       15.401299   14.489651   9.848858
# V20      10.800000   5.403702       16.783921   17.108477   4.494441
# V23      25.600000   6.906519       15.073155   12.817956   7.635444
# V31      38.800000   5.244044        2.302173    8.080842   8.396428
# V17       9.666667   1.000000       17.058722    3.055050   7.371115
# V44      31.600000   3.114482       16.935171   18.801596   5.147815
# V26      38.500000   6.870226        9.628084    7.441438   4.560702
# V4       18.400000   3.209361       16.021860   14.913920   5.224940
# V32      35.400000   5.069517       15.192103    9.933529   7.956130
# V39      29.600000   6.949820       17.181385   10.440307   5.805170
# V2       33.300000   2.863564       14.024978   16.969090   6.066300
# V8       33.000000   5.477226       15.565989    8.648699   6.107373
# V35      38.600000   8.497058       17.131842    5.032395   6.610598
# V51      24.200000   4.764452        7.886698    9.679876   6.693280
# V52      15.400000   2.073644       15.224979   13.198485   6.180615
# V40      42.600000   2.949576       10.894953   15.509674   1.581139
# V41      44.800000   6.534524       14.335271    9.676001   9.654015
# V30      34.000000   4.774935       16.118313   13.982131   5.683309
# V55      34.800000   5.357238        6.964194    9.914636   3.082207
# V29      40.400000   7.700649        6.964194   11.519549   9.407444
# V58      42.200000   4.393177       10.295630    5.639149   8.264381
# V24      33.600000   6.228965       17.711578   18.909654   9.460444
# V6       17.200000  10.425929        6.767570   11.087155  11.388591
# V34      21.400000   5.856620       11.588788    7.216301   5.403702
# V25      35.200000   5.495453       17.008821   17.810109   2.280351
# V38      42.400000   2.345208       15.274161   17.307513   3.507136
# V59      31.800000   7.402702       20.795432   11.606033   6.767570
# V1       29.800000   2.774887       10.027462    6.670832   4.277850
# V14      51.700000   6.308724        7.503333    8.502941   6.693280
# V3       41.600000   3.271085        5.458938   13.078608   5.176872
# V5       15.600000   7.368853       10.497619   15.801899   7.661593
# V60      33.400000   5.630275        9.565563    5.019960   1.000000
# V19      40.600000   5.403702       13.065221   17.023513   9.964939
# V53      24.600000   4.690416        9.984989   12.088217   7.106335
# V50      37.600000   4.847680       10.793517    5.067050   6.978539
# V54      20.400000   2.701851        9.762172   12.357184   6.260990
# V7       37.100000   7.582875        6.542171    8.276473   6.123724
# V42      26.200000   6.685806        6.655825   13.183323   7.765307
# V56      40.500000   6.833740        3.232646    9.895706   3.435113
# V33      29.600000   4.722288        8.105554   18.889150   7.362065
# V57      37.300000   1.673320        5.357238   10.329569   0.894427
#
#
# method          rf        xgb
# feature
# V12       1.095445  13.007690
# V9        1.483240   9.924717
# V10       1.414214  13.794927
# V48       4.929503   9.864076
# V11       0.447214   0.000000
# V45       3.162278   5.856620
# V27       3.420526   2.863564
# V22       5.983310  13.103435
# V21      21.920310   4.242641
# V15       2.774887   5.167204
# V36       7.416198   3.391165
# V46       9.813256  14.272351
# V43      13.183323   5.805170
# V49       2.516611   9.451631
# V47       2.701851   4.878524
# V37       5.761944   6.870226
# V13       5.594640   6.627594
# V28       6.804410   3.420526
# V20       4.816638   7.563068
# V23       3.563706   6.804410
# V31       5.099020   7.224957
# V17       4.041452   8.020806
# V44       3.049590  15.501613
# V26      11.497826  19.176809
# V4       11.344602  12.401613
# V32       6.782330  10.968136
# V39       8.734987  14.570518
# V2       12.349089  26.794589
# V8       13.141537  13.379088
# V35      10.049876  16.949926
# V51       4.636809   9.654015
# V52      12.300406   9.787747
# V40      14.397917  19.375887
# V41       4.969909   8.228001
# V30       6.730527  19.685020
# V55       4.324350  10.425929
# V29       6.066300   7.368853
# V58      11.588788  20.816460
# V24      11.388591  19.320973
# V6       12.581733  11.009087
# V34      12.198361   9.813256
# V25       7.162402  19.766133
# V38       5.727128   4.277850
# V59      10.329569   9.497368
# V1        6.164414  21.004761
# V14       5.495453   2.224860
# V3        8.961027  11.148991
# V5        8.228001  15.241391
# V60       7.823043  18.955210
# V19      10.454664  14.258331
# V53       3.781534  16.592167
# V50      15.089732  13.296616
# V54       7.797435  11.717508
# V7        8.426150  24.146428
# V42       9.418068   7.661593
# V56       4.658326  18.048546
# V33       9.591663  14.842507
# V57       5.310367  13.618003

# %%
model_name = "SVM-rbf"
corr_mean = spearman_per_fold(df_rank, model_name)

plot_corrplot(corr_mean,title=f"Mean Spearman correlation across folds ({model_name})")

# %%
model_name = "KNN"
corr_mean = spearman_per_fold(df_rank, model_name)

plot_corrplot(corr_mean,title=f"Mean Spearman correlation across folds ({model_name})")

# %%
df_compl_fi = pd.read_csv("Results_FS_Distributed_CV/ionosphere_DistributedCVRandom_OutHigh_FeatureImportance_Folds.csv")
df_sota_fi = pd.read_csv("Results_FS_SOTA_CV/ionosphere_SOTA_CV_FeatureImportance_Folds.csv")
df_rank, df_all = ranks_comparison(df_sota_fi,df_compl_fi)
ranking_table = build_ranking_table(df_all,model="SVM-rbf")
display(ranking_table)
# Out:
#          mean_rank                                                 std_rank  \
# method   f_classif kDN_importances mutual_info relief    rf   xgb f_classif
# feature
#  Pulse5        1.4             1.0         1.4    1.0   1.0   1.0  0.547723
#  Pulse8       11.8             4.4         4.8   10.8   6.2   8.2  3.701351
#  Pulse7        3.8             5.2        12.2    2.0   3.0   7.4  0.447214
#  Pulse6       17.8             6.0         2.0   13.8   5.8  14.0  3.563706
#  Pulse3        1.6             9.4         5.4    4.2   2.0   5.0  0.547723
#  Pulse14      12.8            10.8         9.2   14.0  10.2  14.6  1.923538
#  Pulse16      18.6            11.4        19.0   28.0  12.4  16.8  3.049590
#  Pulse24      30.6            12.6        14.0   21.4  13.6  15.8  2.073644
#  Pulse27      22.6            12.8        10.0   27.2   4.2   2.2  2.966479
#  Pulse23      12.2            13.4        14.8   15.0  26.2  23.2  1.923538
#  Pulse4       21.8            13.6        20.6    5.6   6.2  11.2  2.774887
#  Pulse28      29.4            15.2        21.6    5.4   9.6  23.0  3.049590
#  Pulse34      27.4            15.2        14.6   33.0  17.6  11.0  2.880972
#  Pulse13      14.6            15.4        15.6    8.4  30.2  29.8  0.894427
#  Pulse21      10.0            16.0         5.2    7.2  19.0  21.0  1.581139
#  Pulse31       6.0            16.0        11.6   11.4  13.2  19.8  1.414214
#  Pulse33       7.2            16.4         7.4   11.6  11.4  19.8  0.836660
#  Pulse15      11.4            16.8        14.2    3.6  23.4  22.9  3.209361
#  Pulse9        5.6            18.4        25.6   10.0  23.2  22.0  0.547723
# Pulse1         3.2            18.4        32.2   18.6  14.0  19.9  0.447214
#  Pulse12      18.4            18.6        27.4   17.4  19.0  26.2  4.098780
#  Pulse25      14.4            20.4        17.6   18.6  28.2  13.0  3.577709
#  Pulse32      30.4            20.4        22.0   29.6  22.6  25.5  2.509980
#  Pulse11      15.6            21.8        24.2   20.2  30.2  11.2  2.302173
#  Pulse19      22.2            22.6        27.8   24.4  30.4  20.6  1.923538
#  Pulse29       7.6            22.6         6.4   17.8  13.6  22.3  1.516575
#  Pulse10      22.4            24.4        24.2   21.2  19.6  23.8  4.393177
#  Pulse22      21.8            24.4        16.4   28.4  21.2  16.2  3.114482
#  Pulse20      29.6            25.0        26.2   24.4  24.6  15.2  2.073644
#  Pulse18      22.4            26.4        24.4   27.2  13.0  20.6  2.701851
#  Pulse17      26.0            26.8        29.2   18.2  28.8  19.4  3.674235
#  Pulse30      30.4            29.0        31.8   31.4  32.0  15.8  1.949359
#  Pulse26      30.0            30.2        22.0   30.0  25.4  22.6  1.870829
#
#
# method   kDN_importances mutual_info    relief        rf        xgb
# feature
#  Pulse5         0.000000    0.547723  0.000000  0.000000   0.000000
#  Pulse8         2.302173    2.683282  3.768289  1.643168   3.768289
#  Pulse7         4.086563    3.962323  0.000000  0.000000   7.956130
#  Pulse6         3.082207    1.000000  3.033150  0.836660   4.062019
#  Pulse3         5.856620    2.073644  0.836660  0.000000   1.870829
#  Pulse14        4.816638    2.774887  3.162278  2.683282   6.066300
#  Pulse16        7.334848    3.937004  2.000000  2.880972   9.959920
#  Pulse24        7.503333    3.741657  3.209361  2.408319   2.588436
#  Pulse27        7.362065    3.674235  0.836660  0.447214   0.447214
#  Pulse23        3.847077    3.701351  1.224745  4.324350   2.489980
#  Pulse4         9.289779    5.683309  1.816590  0.836660   3.563706
#  Pulse28        9.884331    6.348228  1.341641  3.781534   4.527693
#  Pulse34        7.429670    7.231874  0.000000  3.209361   3.937004
#  Pulse13        9.099451    3.209361  1.140175  1.923538   5.506814
#  Pulse21       12.589678    1.788854  0.836660  3.162278   8.514693
#  Pulse31        7.905694    3.209361  1.949359  4.969909   6.760178
#  Pulse33        7.162402    4.979960  2.073644  1.516575   8.642916
#  Pulse15        7.823043    5.630275  0.894427  2.701851  11.104053
#  Pulse9        10.382678    4.560702  3.316625  2.387467   7.416198
# Pulse1          5.941380    1.303840  3.130495  1.414214  13.584918
#  Pulse12        6.308724    2.607681  2.701851  3.082207   6.379655
#  Pulse25        8.848729    3.974921  3.847077  2.489980   8.888194
#  Pulse32        3.577709    5.431390  2.302173  2.880972   6.383573
#  Pulse11        7.328028    4.086563  3.633180  2.774887  10.134101
#  Pulse19        8.648699    3.834058  3.049590  2.073644  10.667708
#  Pulse29        7.829432    1.516575  4.438468  3.847077  10.034939
#  Pulse10        8.080842    7.854935  3.271085  3.286335   5.630275
#  Pulse22        8.619745    5.504544  2.073644  3.346640   5.449771
#  Pulse20        8.888194    3.492850  1.516575  1.949359   9.602083
#  Pulse18        5.412947    2.190890  1.923538  3.391165  11.844830
#  Pulse17        2.774887    3.033150  0.836660  2.489980   6.066300
#  Pulse30        2.915476    1.643168  0.547723  1.000000   9.093954
#  Pulse26        2.167948    8.185353  2.345208  5.727128   3.714835

# %%
model_name = "SVM-rbf"
corr_mean = spearman_per_fold(df_rank, model_name)

plot_corrplot(corr_mean,title=f"Mean Spearman correlation across folds ({model_name})")

# %%
model_name = "KNN"
corr_mean = spearman_per_fold(df_rank, model_name)

plot_corrplot(corr_mean,title=f"Mean Spearman correlation across folds ({model_name})")

# %% [markdown]
# Con los rankings obtenemos 2 conclusiones:
# * Nuestro método es el que más variabilidad muestra entre folds, seguido de XGB. Esto es un poco preocupante porque no dejamos de ser un método de filtro, pero claro, también dependerá de la cantidad de variables que entran, eso hay que estudiarlo mejor.
# * En general los rankings entre métodos no muestran una correlación alta. En algunos casos hay algún método con una correlación de 0.7 ó 0.8, pero en general son en torno a 0.5 o bajas.
